# %%
import pandas as pd

file_path = "../data/rawdata/Electronics.jsonl.gz"

# Read only the first 10,000 reviews
df = pd.read_json(
    file_path,
    lines=True,
    compression="gzip",
    nrows=11000
)

print(df.shape)
df.head()

# Save as CSV
output_file = "../data/finalised/amazon_electronics_11000.csv"
df.to_csv(output_file, index=False)

print("CSV file created successfully!")
print(f"Number of reviews: {len(df)}")
print(f"Saved to: {output_file}")
# Out:
# (11000, 10)
# CSV file created successfully!
# Number of reviews: 11000
# Saved to: ../data/finalised/amazon_electronics_11000.csv

# %%
# Number of rows and columns
print("Dataset shape:", df.shape)

# Column names
print("\nColumns:")
print(df.columns.tolist())

# Information about the dataset
print("\nDataset information:")
df.info()
# Out:
# Dataset shape: (11000, 10)
#
# Columns:
# ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase']
#
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rating             11000 non-null  int64
#  1   title              11000 non-null  str
#  2   text               11000 non-null  str
#  3   images             11000 non-null  object
#  4   asin               11000 non-null  str
#  5   parent_asin        11000 non-null  str
#  6   user_id            11000 non-null  str
#  7   timestamp          11000 non-null  datetime64[ms]
#  8   helpful_vote       11000 non-null  int64
#  9   verified_purchase  11000 non-null  bool
# dtypes: bool(1), datetime64[ms](1), int64(2), object(1), str(5)
# memory usage: 5.6+ MB

# %%
df = pd.read_csv("../data/finalised/amazon_electronics_11000.csv")
dataset_summary = pd.DataFrame({
    "Attribute": df.columns,
    "Data Type": df.dtypes.astype(str),
    "Non-Null Values": df.notnull().sum().values,
    "Missing Values": df.isnull().sum().values,
    "Unique Values": df.nunique().values
})

print(dataset_summary)

# %%
#To find the exact column
print(df.columns.tolist())
# Out:
# ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase']

# %% [markdown]
# ## Step 1: Data Cleaning

# %%
# Keep only the required columns
df = df[['title','text', 'rating']]

# Display the first five rows
df.head()
# Out:
#                                          title  \
# 0            Smells like gasoline! Going back!
# 1      Didn’t work at all lenses loose/broken.
# 2                                   Excellent!
# 3                       Great laptop backpack!
# 4  Best Headphones in the Fifties price range!
#
#                                                 text  rating
# 0  First & most offensive: they reek of gasoline ...       3
# 1  These didn’t work. Idk if they were damaged in...       1
# 2  I love these. They even come with a carry case...       5
# 3  I was searching for a sturdy backpack for scho...       5
# 4  I've bought these headphones three times becau...       5

# %%
# Check for missing values
df.isnull().sum()
# Out:
# title     0
# text      0
# rating    0
# dtype: int64

# %%
# Remove rows where review text is missing
df = df.dropna(subset=['text'])

print(df.shape)
# Out:
# (11000, 3)

# %%
# Remove duplicate reviews
df = df.drop_duplicates(subset=['text'])

print(df.shape)
# Out:
# (10521, 3)

# %%
# Remove duplicate reviews
df = df.drop_duplicates(subset=['text'])

print(df.shape)
# Out:
# (10521, 3)

# %%
# Length of each review
df['review_length'] = df['text'].str.len()

df['review_length'].describe()
# Out:
# count    10521.000000
# mean       404.642239
# std        700.240001
# min          1.000000
# 25%         66.000000
# 50%        167.000000
# 75%        416.000000
# max       9989.000000
# Name: review_length, dtype: float64

# %%
# Remove empty reviews
df = df[df['text'].str.strip() != ""]

print(df.shape)
# Out:
# (10520, 4)

# %%
df.to_csv("../data/processed/cleaned_reviews_latest.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.
